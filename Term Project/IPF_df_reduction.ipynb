# %%
import pandas as pd

df = pd.read_csv('ipf.csv')

df.info()
# Out:
# C:\Users\jackm\AppData\Local\Temp\ipykernel_22284\3744460308.py:3: DtypeWarning: Columns (33,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ipf.csv')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372159 entries, 0 to 1372158
# Data columns (total 42 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Name              1372159 non-null  object
#  1   Sex               1372159 non-null  object
#  2   Event             1372159 non-null  object
#  3   Equipment         1372159 non-null  object
#  4   Age               1011712 non-null  float64
#  5   AgeClass          1057140 non-null  object
#  6   BirthYearClass    1074518 non-null  object
#  7   Division          1370950 non-null  object
#  8   BodyweightKg      1357103 non-null  float64
#  9   WeightClassKg     1356035 non-null  object
#  10  Squat1Kg          580439 non-null   float64
# ...

# %%
df.head()
# Out:
#                Name Sex Event Equipment   Age AgeClass BirthYearClass  \
# 0         Amy Clair   F   SBD       Raw  36.0    35-39          24-39
# 1      Ruby Olthoff   F   SBD       Raw  17.0    16-17          14-18
# 2     Wai Hang Wong   M   SBD       Raw  21.0    20-23          19-23
# 3  Jonathan Chan #2   M   SBD       Raw  23.0    20-23          19-23
# 4      Sung Hoon Ok   M   SBD       Raw  22.0    20-23          19-23
#
#      Division  BodyweightKg WeightClassKg  ...    Country  State  Federation  \
# 0        Open         75.54            76  ...  Australia    NaN        APLA
# 1  Sub-Junior         69.44            76  ...  Australia    NaN        APLA
# 2      Junior         70.64            74  ...  Australia    NaN        APLA
# 3      Junior         81.34            83  ...  Australia    NaN        APLA
# 4      Junior         92.42            93  ...  Australia    NaN        APLA
#
#    ParentFederation        Date  MeetCountry  MeetState  MeetTown  \
# ...

# %%
df_registration = df[['Name', 'Sex', 'Event', 'Equipment', 'Division', 'WeightClassKg', 'Squat1Kg', 'Bench1Kg', 'Deadlift1Kg']]
df_registration['ProjectedTotal'] = df_registration[['Squat1Kg', 'Bench1Kg', 'Deadlift1Kg']].sum(axis=1)
df_registration.head()
# Out:
# C:\Users\jackm\AppData\Local\Temp\ipykernel_22284\2986297730.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_registration['ProjectedTotal'] = df_registration[['Squat1Kg', 'Bench1Kg', 'Deadlift1Kg']].sum(axis=1)
#                Name Sex Event Equipment    Division WeightClassKg  Squat1Kg  \
# 0         Amy Clair   F   SBD       Raw        Open            76     132.5
# 1      Ruby Olthoff   F   SBD       Raw  Sub-Junior            76     135.0
# 2     Wai Hang Wong   M   SBD       Raw      Junior            74     185.0
# 3  Jonathan Chan #2   M   SBD       Raw      Junior            83     195.0
# 4      Sung Hoon Ok   M   SBD       Raw      Junior            93     237.5
#
#    Bench1Kg  Deadlift1Kg  ProjectedTotal
# ...

# %%
df_registration.size
# Out:
# 13721590

# %%
df_registration = df_registration[df_registration['Event'] == 'SBD']

# %%
df_registration = df_registration.dropna()
df_registration.size
# Out:
# 5651330

# %%
df_registration.head()
# Out:
#                Name Sex Event Equipment    Division WeightClassKg  Squat1Kg  \
# 0         Amy Clair   F   SBD       Raw        Open            76     132.5
# 1      Ruby Olthoff   F   SBD       Raw  Sub-Junior            76     135.0
# 2     Wai Hang Wong   M   SBD       Raw      Junior            74     185.0
# 3  Jonathan Chan #2   M   SBD       Raw      Junior            83     195.0
# 4      Sung Hoon Ok   M   SBD       Raw      Junior            93     237.5
#
#    Bench1Kg  Deadlift1Kg  ProjectedTotal
# 0      82.5        140.0           355.0
# 1      70.0        160.0           365.0
# 2     105.0        200.0           490.0
# 3     130.0        215.0           540.0
# 4     147.5        257.5           642.5

# %%
df_test = df.dropna()
df_test.size
# Out:
# 0

# %%
dfreg_sample = df_registration.sample(n=2000, random_state=42).reset_index().drop('index', axis=1)
dfreg_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            2000 non-null   object
#  1   Sex             2000 non-null   object
#  2   Event           2000 non-null   object
#  3   Equipment       2000 non-null   object
#  4   Division        2000 non-null   object
#  5   WeightClassKg   2000 non-null   object
#  6   Squat1Kg        2000 non-null   float64
#  7   Bench1Kg        2000 non-null   float64
#  8   Deadlift1Kg     2000 non-null   float64
#  9   ProjectedTotal  2000 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 156.4+ KB

# %%
dfreg_sample.to_csv('ipf_reg_2000.csv', index=False)
