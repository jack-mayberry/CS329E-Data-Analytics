# %% [markdown]
# # Term Project
#
# Name: Lily Nguyen
#
# UT Eid: lmn934
#
# Name: John "Jack" Mayberry
#
# UT Eid: jmm23398

# %% [markdown]
# ## 1. Description
#
# The goal of this project assignment is to develop a data analytics project using a real-world
# dataset. Students should select a public dataset, think about a research project, for example,
# t-test, two-sample hypothesis tests, regression models, classification, clustering, or any data
# analytic task, implement the data model (using libraries or without libraries), evaluate, and
# interpret the results. You can apply more than one data model.

# %% [markdown]
# ## 2. Public Dataset
#
# Requirements:
# * The dataset must not be very large
# * You can reuse one of the assignment datasets

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Add your code here
# NOTE: get the csv files outside of the data folder when want to use so file path doesn't get messed up, + for better organization
# I was just messing around with the files earlier, didn't decide which dataset to use

# df = pd.read_csv('circuits.csv')
#df = pd.read_csv('results.csv')
# df = pd.read_csv('seasons.csv')
# df = pd.read_csv('sprint_results.csv')
df = pd.read_csv('ipf.csv')
df.head()
# Out:
# C:\Users\jackm\AppData\Local\Temp\ipykernel_12272\1576625527.py:9: DtypeWarning: Columns (33,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('ipf.csv')
#                Name Sex Event Equipment   Age AgeClass BirthYearClass  \
# 0         Amy Clair   F   SBD       Raw  36.0    35-39          24-39
# 1      Ruby Olthoff   F   SBD       Raw  17.0    16-17          14-18
# 2     Wai Hang Wong   M   SBD       Raw  21.0    20-23          19-23
# 3  Jonathan Chan #2   M   SBD       Raw  23.0    20-23          19-23
# 4      Sung Hoon Ok   M   SBD       Raw  22.0    20-23          19-23
#
#      Division  BodyweightKg WeightClassKg  ...    Country  State  Federation  \
# 0        Open         75.54            76  ...  Australia    NaN        APLA
# 1  Sub-Junior         69.44            76  ...  Australia    NaN        APLA
# 2      Junior         70.64            74  ...  Australia    NaN        APLA
# 3      Junior         81.34            83  ...  Australia    NaN        APLA
# 4      Junior         92.42            93  ...  Australia    NaN        APLA
#
#    ParentFederation        Date  MeetCountry  MeetState  MeetTown  \
# 0               IPF  2024-10-20    Australia         SA       NaN
# 1               IPF  2024-10-20    Australia         SA       NaN
# 2               IPF  2024-10-20    Australia         SA       NaN
# 3               IPF  2024-10-20    Australia         SA       NaN
# 4               IPF  2024-10-20    Australia         SA       NaN
#
#                  MeetName  Sanctioned
# 0  AUPC Powerlifting Open         Yes
# 1  AUPC Powerlifting Open         Yes
# 2  AUPC Powerlifting Open         Yes
# 3  AUPC Powerlifting Open         Yes
# 4  AUPC Powerlifting Open         Yes
#
# [5 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372159 entries, 0 to 1372158
# Data columns (total 42 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Name              1372159 non-null  object
#  1   Sex               1372159 non-null  object
#  2   Event             1372159 non-null  object
#  3   Equipment         1372159 non-null  object
#  4   Age               1011712 non-null  float64
#  5   AgeClass          1057140 non-null  object
#  6   BirthYearClass    1074518 non-null  object
#  7   Division          1370950 non-null  object
#  8   BodyweightKg      1357103 non-null  float64
#  9   WeightClassKg     1356035 non-null  object
#  10  Squat1Kg          580439 non-null   float64
#  11  Squat2Kg          575078 non-null   float64
#  12  Squat3Kg          562169 non-null   float64
#  13  Squat4Kg          328 non-null      float64
#  14  Best3SquatKg      992848 non-null   float64
#  15  Bench1Kg          808587 non-null   float64
#  16  Bench2Kg          801605 non-null   float64
#  17  Bench3Kg          782633 non-null   float64
#  18  Bench4Kg          1261 non-null     float64
#  19  Best3BenchKg      1287801 non-null  float64
#  20  Deadlift1Kg       593099 non-null   float64
#  21  Deadlift2Kg       584551 non-null   float64
#  22  Deadlift3Kg       566448 non-null   float64
#  23  Deadlift4Kg       475 non-null      float64
#  24  Best3DeadliftKg   1009019 non-null  float64
#  25  TotalKg           1298803 non-null  float64
#  26  Place             1372159 non-null  object
#  27  Dots              1285497 non-null  float64
#  28  Wilks             1285497 non-null  float64
#  29  Glossbrenner      1285497 non-null  float64
#  30  Goodlift          1251665 non-null  float64
#  31  Tested            1228468 non-null  object
#  32  Country           798369 non-null   object
#  33  State             243148 non-null   object
#  34  Federation        1372159 non-null  object
#  35  ParentFederation  1372159 non-null  object
#  36  Date              1372159 non-null  object
#  37  MeetCountry       1372159 non-null  object
#  38  MeetState         745941 non-null   object
#  39  MeetTown          1150296 non-null  object
#  40  MeetName          1372159 non-null  object
#  41  Sanctioned        1372159 non-null  object
# dtypes: float64(22), object(20)
# memory usage: 439.7+ MB

# %% [markdown]
# ## 3. Define a Project (4 points)
#
# Define a data science research question based on the selected dataset. You can select one of
# the listed datasets or search on the web, and pick up one of the available public datasets.
# You should describe the following items
# 1. What is your data set about?
# 2. Clean up your data and reduce it to no more than 2000 observations if your data set is
# very large.
# 3. What is exactly your research question? What do you want to learn from data? What
# is your learning model ,e.g., a Classification, Clustering, etc?
# 4. What is your current expectations about the results?
# 5. How do you want to evaluate your project? How to access the correctness of your
# model? How well would you expect that the model will work?

# %% [markdown]
# #### Some notes by Lily, project recommendation:
#
# Potential TOpic: Predict the podium of the F1 Hungarian Grand Prix (August 1-3, 2025) based on previous data of driver race performance such as qualifiying times, race times, pit-stop times/efficiency, position, etc... (lots of data to use)
#
# Or we run ML models to predict race placements of previous races (but I thought it'd be cool to predict future races so we can go back to )
#
# Note: since there are only 20 drivers on the grid, the accessible datasets won't likely be too big to use. thus this is a good potential project idea
#
# Possible models: LR, SVM, RandomForest, decidion trees, adaboost classiifer/other ensemble methods (basicalluy just we want make predictions)
#
# Link to Dataset: https://www.kaggle.com/datasets/rohanrao/formula-1-world-championship-1950-2020?resource=download
#
# #### Another recommendation for proj:
# Predicting outcomes of Figure Skating World Championships based on from current season
#
# from: ISU Grand Prix data, other int'l competitions
#
# probably similar models and setup as the F1-project
#
# Link to men's figure skating data (world championships): https://www.kaggle.com/datasets/mitchellfriess/fsscores
#
# ISU Grand Prix Series dataset: ?? can't find yet
#
# Link to under-rotation jump data: https://www.kaggle.com/datasets/sarazany/figure-skating-underrotations-and-flutzlip (not sure what to do with this so just putting it here)
#
# Interesting paper: https://dash.harvard.edu/server/api/core/bitstreams/322438c0-3bc3-4cbc-b32d-c40f175fac4a/content
#
# look for other data on this topic bcs couldn't find much yet
#
# #### Big Picture + motivations
#
# If we're able to predict the winners, we can get big rewards (e.g. efficiency, money, whatever)
#
# Formula1 - if we can design an ML model to accurately predict race winner results, we can get involved in race-betting and make $$ while letting our machine do the work
#
# * for the teams themselves: can predict optimal performance metrics and strategies, like when to make pit stops, how to allocate energy, lots of things... all to maximize racing performance
#
# Figure Skating - ... similar stuff basically
#
#
# #### Some notes on model evaluation
#
# RMSE - root mean-squared error
#
# MAE - mean absolute error
#
# R^2 - based on corr coeff

# %% [markdown]
# ---
# #### Notes from Jack, project ideas for IPF dataset
#
# A.
#
# Could predict whether a lifter competed equipped or raw based on ratios of (specific lift) / (total) and other features. This would be fairly easy to implement and test (easy 1 / 0 prediction) but isn't that useful in the real world. Similar to the prediction on the type of housing (house, apartment etc)
#
# B.
#
# Could determine how much home-field advantage lifters have when competing in their home country as opposed to internationally. This would require mapping the federation to the country of origin, which would take some work. We could select the most prominent countries, however, as the dataset is pretty massive.
#
# C.
#
# Could use a clustering model to build flights for local meets. Large meets have enough people for flights to be determined by division, but smaller meets are mixed up. This could make the flights optimized for the spotters and loaders to reduce the manual workload. I like this idea the best so far, but want to see what all needs to be done.
#
# ---
#
# I like the idea of the F1 dataset. I'm planning to play around with the IPF data and see what I can pull from it. If it's too much of a pain to work with, I'm down to look at the race data.
#
# ### Note:
#
# The ipf dataset is huge so I have another notebook that I used to reduce the size down to 2k lines

# %%
# Start coding here:

# %% [markdown]
# ## 4. Implementation (6 points)
#
# * You need to implement your project in python. You are allowed to use any Machine
# Learning Library like scikit-learn1. You are also allowed to implement your project
# without using any libraries.
# * You can use Jupyter Notebooks to implement your project and provide your documen-
# tations.
# * You code should be completed and be compilable without any errors. We should be
# able to read your documents, and be able to run your project.
# * Run your implementation (on your Laptop or on Cluster if data is large) and generate
# the results.
# * Provide the interpretations of your results.
# * What can you do to improve your results? Apply your ideas to improve your results.
# * Provide any references that you have used.

# %%
# Add your code here

# %% [markdown]
# ## 5. Create Recorded Presentation Video (5 points)
#
# Create a document or a presentation (You can create a presentation using your Jupyter
# notebook, or create a powerpoint presentation, or other formats) to describe your
# project and results
# * Describe your code.
# * Describe the results of your project in a professional way.
# * You may want to visualization diagrams and describe the results based on some dia-
# grams - but having diagrams is not a MUST have to get the full credit.
# * Describe the model and results of your project in a way that every person in this field
# can read, enjoy and understand.
#
# Record your presentation in form of a video recording. Present your talk on your laptop
# computer and record it using a desktop recording software.
#
# You should use your webcam so that we can identify who is presenter.
#
# You have the following 3 options to create a presentation video:
#
# * <u>**Method 1</u>:** You can use the Panopto Deskop Recorder. You can find this software
# and documentations here https://www.panopto.com/.
# * <u>**Method 2</u>:** You can record your presentation using ZOOM client application, start
# your zoom client, start a zoom meeting (you will be the only participant), click on
# share your desktop, turn on camera and record your presentation, end the zoom session
# and you will get a MP4 video file of your presentation. Upload the file to Blackboard
# system
# * <u>**Method 3</u>:** Alternatively, you can use any desktop recording software, generate a MP4
# file and upload MP4 to blackboard, or upload it to some other cloud storage (like google
# Drive, DropBox) and share with us the URL Link of your presentation (submit the link
# in Blackboard).
#
# * <u>**Note 1</u>:** Your video presentation should be between 8 minutes to maximum 15 minutes
# long (Min 8 mi, Max 15 min)
# * <u>**Note 3</u>:** You should turn on your Web Camera so that we can see your face during the
# presentation, and be able to identify the presenter.
# Grading will be based on quality of your presentation, and correct describing of algorithms
# or concepts.

# %% [markdown]
# ## 5.1 Turnins
#
# * Submit your Jupyter Notebook or Python code
# * Submit your documentation (It can be part of your Jupyter Notebook or a separate file
# like PPT or Docs, or other formats)
# * Submit your Video Presentation. Upload your video file to Canvas Panopto Video
# Gallery.

# %% [markdown]
# ## 5.2 Grading Criteria
#
# Your term project will be graded based on the following rubrics:
# 1. Correct description of the selected dataset.
# 2. Correctness of your data preparation and cleanup approach.
# 3. General Correctness of data analysis approach.
# 4. Correctness of your implementation and results.
# 5. Correctness of your interpretations of the results.
# 6. Providing all references.
